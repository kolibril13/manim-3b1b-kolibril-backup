# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
from skimage import io
im = io.imread('proj_MBA-1.tif')
print(im.shape)
# Out:
# (500, 1099, 824)

# %%
ls
# Out:
# files/           __pycache__/          tomo2.py            tomo_sino.py
# media/           reconstructed_02.tif  tomo_lines.py       Untitled.ipynb
# proj_MBA-1.tif*  tomo1.py              tomo_lines_text.py

# %%
plt.imshow(im[:,:,400])

# %%
plt.imshow(np.flip(im[0,:,:],0))

# %%
im2= np.array([np.flip(im[i,:,:],0) for i in range(0, im.shape[0])])

# %%
im2.shape
# Out:
# (500, 1099, 824)

# %%
io.imsave("proj_RAW-1b.tif",im2)

# %%
?? io.imsave
