# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
def disp(x, sep='.0f'): 
    plt.figure(figsize = (16,9))
    sns.heatmap(x,annot=False,fmt=sep, cmap="YlGnBu"); # Change range with: vmin=0, vmax=1

# %%
x=np.load("maske.npy")
disp(x)
